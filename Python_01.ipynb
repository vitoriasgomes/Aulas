# %% [markdown]
# # Crash Course de Python

# %% [markdown]
# ## Operações Simples

# %%
2 + 2

# %%
2 * 3

# %%
2**3

# %%
5/2

# %%
5//2

# %%
5%2

# %%
2+3j*(1-1j)

# %%
1j*1j

# %%
(1j**2)

# %% [markdown]
# ### Strings

# %%
"teste"

# %%
"teste "+"de strings"

# %%
"teste"+' de strings'

# %%
3*"teste "

# %%
"teste"-"te"

# %%
"teste teste teste"/3

# %%
1e6

# %%
1_000_000.0

# %%
1e6 == 1_000_000.0

# %% [markdown]
# ### Booleanos

# %%
2 > 3

# %%
(2<3) and (4<5)

# %%
(2<3) and (6<5)

# %%
3 != 5

# %% [markdown]
# ## Tipos e Classes

# %%
type(3)

# %%
type(3.0)

# %%
type(1j)

# %%
type("Olá")

# %%
type('1')

# %%
type(True)

# %%
type(true)

# %%
int("3")

# %%
str(3.1415926536)

# %%
float('3.1415926')

# %% [markdown]
# ## Variáveis

# %%
a = 3

# %%
print (a)

# %%
base = 3
altura = 4

# %%
area_triangulo = base*altura/2
print(area)

# %% [markdown]
# Leia e procure seguir o [PEP - Guia de Estilo](https://wiki.python.org.br/GuiaDeEstilo)

# %%
C = 299_792_458

# %%
snake_case = "cases"

# %% [markdown]
# ### Imprimindo

# %%
print(base)

# %%
print("A área de um triângulo de base ",base," e altura ",altura," é "+str(area))

# %%
print("A área de um triângulo de base %f e altura %f é %f "%(base,altura,area))

# %%
print("A área de um triângulo de base {2:.2f} e altura {0} é {1} ".format(altura,area,base))

# %%
print(f"A área de um triângulo de base {base} e altura {altura} é {area} ")

# %% [markdown]
# ### Tipagem dinâmica

# %%
a = 1
print(type(a))

# %%
a = "Um"
print(type(a))

# %% [markdown]
# Inteiros, floats e strings são "immutable objects"

# %%
a = 42
id(a)

# %%
a = 43
id(a)

# %% [markdown]
# O objeto é criado, destruído e recriado

# %%
# %%html
# <img src="https://i.pinimg.com/originals/31/3d/fa/313dfa6e95306722261b7ae129c74524.jpg" width=300;"/>
